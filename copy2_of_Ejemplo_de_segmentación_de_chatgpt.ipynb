# %% [markdown]
# <a href="https://colab.research.google.com/github/crodriguezbay/MLforMkting/blob/main/copy2_of_Ejemplo_de_segmentacio%CC%81n_de_chatgpt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div >
# <img src = "figs/bannerMLMkting.png" />
# </div>

# %% [markdown]
# # Ejemplo generado a través de chat gpt de segmentación de clientes:
#
#
# ## Solicitud hecha a chatgpt:
#
#
# With the case I will going to give you, would you help me to build a random sample that allows you to recreate an example of this case and the process to build a segmentation in python?
#
#
# #### Segmentación y Targeting
# #### Caso: ESSEC Business School
#
# At the time of this writing, ESSEC Business School is ranked #6 among European Business Schools (Financial Times). While one of its flagship programs is its Master In Management (#6 worldwide, FT ranking), the school has a significant executive education activity, mostly located on its La Défense campus (right on the outskirt of Paris).
# Executive Education is typically split into two categories: customized programs and open-enrollment programs. ESSEC is ranked #3 worldwide for customized programs (i.e., programs designed specifically for a company and its employees) and #16 for open-enrollment programs (i.e., general programs targeting a wide audience of business executives).
#
# Among the open-enrollment programs, one of the degrees delivered by ESSEC Business School is its Executive MBA. EMBA students are fairly senior in their fields and possess considerable work experience. Participants in an EMBA program typically hope to hone their leadership skills, accelerate their careers or change professional orientation.
#
# The Management of ESSEC Business School Executive Education (EEE) wishes to improve the experience (and ranking) of the program and customize its content to the varying needs of the audience. To that avail, the program would offer several modules throughout the year in smaller groups, and interested participants would sign into the module(s) of their choice.
#
#
# Of course, the design of customized modules requires a better understanding of why participants decided to join the ESSEC Executive MBA in the first place: their needs, desires, frustrations, and motivations. Management decided to survey current and past participants and ask them about their motivations for joining the program.
#
#
# ##### Segmentation questions (bases)
#
# Respondents were asked to rate on a 1-5 scale whether the following factors were important in their choices to join the ESSEC Executive MBA:
#
# Networking
# Reputation of the school
# Changing company
# Academic knowledge
# Cost-driven
# Location
# Ranking of the program
# Increasing your salary
# Launching your own company
# Personal development
# Changing career
# Obtaining a promotion
# Benchmarking yourself
# Getting out of the office
# Broadening your horizon
# International perspective
# Improving English
# Improving leadership skills
#
#
# ##### Discriminant variables (descriptors)
# The survey included a few descriptors:
#
# Gender
# Country
# Age
# Years of professional experience
# Financed by your company
#
# Question 1
# Run a segmentation analysis and decide on an appropriate number of segments. Justify your choice. Remember that choosing the “right” number of segments is not always straightforward and depends on several factors, such as statistical criteria, managerial considerations, practical constraints, targetability of the segments, etc.

# %% [markdown]
# ## Análisis de respuesta generada:
#
# ### 1. Importación de librerias requeridas para resolver el ejercicio:
#     - Pandas
#     - Numpy
#     - Programas de Scikit learn Standard Scaler, Kmeans, silhoette score
#     - pyplot de matplotlib

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 2. Generación de conjuntos de datos aleatorios a partir de las preguntas:
#
# Se generan respuestas aleatorias para estudiantes
#
#     - Networking
#     - Reputation of the school
#     - Changing company
#     - Academic knowledge
#     - Cost-driven
#     - Location
#     - Ranking of the program
#     - Increasing your salary
#     - Launching your own company
#     - Personal development
#     - Changing career
#     - Obtaining a promotion
#     - Benchmarking yourself
#     - Getting out of the office
#     - Broadening your horizon
#     - International perspective
#     - Improving English
#     - Improving leadership skills

# %%
# Simulating data for 100 respondents
np.random.seed(42)

# Generating segmentation questions (1-5 scale)
segmentation_questions = ['Networking', 'Reputation_of_school', 'Changing_company', 'Academic_knowledge',
                          'Cost_driven', 'Location', 'Ranking_of_program', 'Increasing_salary',
                          'Launching_own_company', 'Personal_development', 'Changing_career',
                          'Obtaining_promotion', 'Benchmarking_yourself', 'Getting_out_of_office',
                          'Broadening_horizon', 'International_perspective', 'Improving_English',
                          'Improving_leadership_skills']

# Random responses for segmentation questions (scale 1-5)
data = np.random.randint(1, 6, size=(100, len(segmentation_questions)))

# %%
print(data)
print(data.shape)
# Out:
# [[4 5 3 ... 2 4 5]
#  [1 4 2 ... 1 3 5]
#  [3 5 1 ... 4 4 5]
#  ...
#  [2 3 5 ... 1 1 5]
#  [4 3 4 ... 4 4 4]
#  [3 5 4 ... 5 1 1]]
# (100, 18)

# %% [markdown]
# Se generan respuestas aleatorias para descriptores:
#
#     - Gender
#     - Country
#     - Age
#     - Years if experience
#     - Company financed

# %%
# Adding descriptors

genders = np.random.choice(['Male', 'Female'], size=100)
countries = np.random.choice(['France', 'Germany', 'UK', 'USA'], size=100)
ages = np.random.randint(30, 60, size=100)
years_experience = np.random.randint(5, 30, size=100)
company_financed = np.random.choice(['Yes', 'No'], size=100)

# %%
print('genders')
print(genders)
print('countries')
print(countries)
# Out:
# genders
# ['Male' 'Female' 'Female' 'Female' 'Female' 'Male' 'Female' 'Female'
#  'Male' 'Male' 'Female' 'Female' 'Male' 'Female' 'Male' 'Male' 'Male'
#  'Male' 'Female' 'Male' 'Male' 'Female' 'Male' 'Female' 'Female' 'Female'
#  'Male' 'Female' 'Female' 'Male' 'Female' 'Female' 'Female' 'Female'
#  'Female' 'Male' 'Female' 'Female' 'Male' 'Male' 'Male' 'Female' 'Male'
#  'Female' 'Female' 'Male' 'Male' 'Female' 'Male' 'Female' 'Male' 'Male'
#  'Male' 'Female' 'Male' 'Female' 'Female' 'Female' 'Female' 'Male'
#  'Female' 'Female' 'Male' 'Female' 'Male' 'Female' 'Male' 'Female' 'Male'
#  'Female' 'Female' 'Male' 'Male' 'Male' 'Male' 'Female' 'Female' 'Male'
#  'Female' 'Male' 'Male' 'Female' 'Female' 'Female' 'Female' 'Female'
#  'Female' 'Female' 'Male' 'Male' 'Male' 'Male' 'Male' 'Female' 'Male'
#  'Male' 'Male' 'Male' 'Male' 'Male']
# countries
# ['UK' 'USA' 'Germany' 'France' 'Germany' 'Germany' 'USA' 'Germany' 'UK'
#  'Germany' 'Germany' 'Germany' 'France' 'France' 'UK' 'UK' 'France' 'UK'
#  'France' 'USA' 'Germany' 'Germany' 'UK' 'France' 'France' 'UK' 'France'
#  'USA' 'Germany' 'UK' 'UK' 'France' 'UK' 'USA' 'France' 'France' 'France'
#  'France' 'USA' 'France' 'UK' 'USA' 'Germany' 'Germany' 'UK' 'UK' 'USA'
#  'Germany' 'Germany' 'Germany' 'Germany' 'Germany' 'France' 'UK' 'France'
#  'Germany' 'USA' 'USA' 'Germany' 'Germany' 'USA' 'France' 'France'
#  'Germany' 'France' 'USA' 'France' 'Germany' 'USA' 'France' 'UK' 'USA'
#  'USA' 'UK' 'UK' 'USA' 'UK' 'Germany' 'Germany' 'Germany' 'USA' 'UK' 'UK'
#  'France' 'France' 'UK' 'UK' 'UK' 'USA' 'UK' 'France' 'USA' 'UK' 'France'
#  'USA' 'UK' 'UK' 'UK' 'USA' 'France']

# %% [markdown]
# Se crean los conjuntos de datos sobre los que se va a hacer la segmentación:

# %%
# Creating a DataFrame
df = pd.DataFrame(data, columns=segmentation_questions)
dfSegmented=df[segmentation_questions]
'''df['Gender'] = genders
df['Country'] = countries
df['Age'] = ages
df['Years_of_experience'] = years_experience
df['Company_financed'] = company_financed'''
# Out:
# "df['Gender'] = genders\ndf['Country'] = countries\ndf['Age'] = ages\ndf['Years_of_experience'] = years_experience\ndf['Company_financed'] = company_financed"

# %%
dfSegmented
# Out:
#     Networking  Reputation_of_school  Changing_company  Academic_knowledge  \
# 0            4                     5                 3                   5
# 1            1                     4                 2                   5
# 2            3                     5                 1                   2
# 3            3                     1                 4                   2
# 4            5                     2                 5                   2
# ..         ...                   ...               ...                 ...
# 95           2                     4                 2                   2
# 96           4                     2                 4                   2
# 97           2                     3                 5                   5
# 98           4                     3                 4                   1
# 99           3                     5                 4                   2
#
#     Cost_driven  Location  Ranking_of_program  Increasing_salary  \
# 0             5         2                   3                  3
# 1             4         1                   1                  3
# 2             4         1                   4                  2
# 3             4         2                   2                  4
# 4             1         4                   4                  4
# ..          ...       ...                 ...                ...
# 95            4         2                   3                  3
# 96            5         5                   5                  1
# 97            1         4                   4                  5
# 98            1         4                   4                  1
# 99            2         1                   5                  4
#
#     Launching_own_company  Personal_development  Changing_career  \
# 0                       3                     5                4
# 1                       3                     2                4
# 2                       2                     1                2
# 3                       5                     2                2
# 4                       5                     1                5
# ..                    ...                   ...              ...
# 95                      2                     5                4
# 96                      4                     5                1
# 97                      3                     2                3
# 98                      3                     5                5
# 99                      2                     5                1
#
#     Obtaining_promotion  Benchmarking_yourself  Getting_out_of_office  \
# 0                     3                      5                      2
# 1                     4                      3                      4
# 2                     5                      2                      4
# 3                     4                      2                      2
# 4                     5                      1                      1
# ..                  ...                    ...                    ...
# 95                    3                      5                      2
# 96                    4                      2                      1
# 97                    2                      5                      2
# 98                    4                      5                      1
# 99                    3                      5                      5
#
#     Broadening_horizon  International_perspective  Improving_English  \
# 0                    4                          2                  4
# 1                    4                          1                  3
# 2                    4                          4                  4
# 3                    4                          4                  1
# 4                    1                          1                  4
# ..                 ...                        ...                ...
# 95                   5                          1                  3
# 96                   3                          1                  1
# 97                   4                          1                  1
# 98                   1                          4                  4
# 99                   3                          5                  1
#
#     Improving_leadership_skills
# 0                             5
# 1                             5
# 2                             5
# 3                             5
# 4                             3
# ..                          ...
# 95                            2
# 96                            4
# 97                            5
# 98                            4
# 99                            1
#
# [100 rows x 18 columns]

# %% [markdown]
# Se estandarizan datos numéricos:

# %%
# Normalizing numeric data
scaler = StandardScaler()
df_normalized = pd.DataFrame(scaler.fit_transform(dfSegmented),columns=segmentation_questions)

# %% [markdown]
# Se selecciona el número apropiado de segmentos:

# %%
# Choosing the right number of segments using the Elbow Method
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, random_state=42)
    kmeans.fit(df_normalized)
    wcss.append(kmeans.inertia_)

# Plotting the Elbow Method
plt.plot(range(1, 11), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()

# Choosing optimal clusters (e.g., from elbow point, k=6 here as an example)
kmeans = KMeans(n_clusters=6, random_state=42)
clusters = kmeans.fit_predict(df_normalized)

# Adding cluster labels to the original dataset
dfSegmented['Cluster'] = clusters

# Interpretation of clusters
cluster_summary = dfSegmented.groupby('Cluster').mean()
print(cluster_summary)

# Evaluating with silhouette score
sil_score = silhouette_score(df_normalized, clusters)
print(f'Silhouette Score: {sil_score}')
# Out:
#          Networking  Reputation_of_school  Changing_company  \
# Cluster
# 0          3.857143              2.142857          3.642857
# 1          1.250000              3.083333          2.416667
# 2          3.277778              2.388889          3.055556
# 3          2.105263              3.000000          2.842105
# 4          3.428571              2.428571          2.571429
# 5          3.913043              4.000000          3.260870
#
#          Academic_knowledge  Cost_driven  Location  Ranking_of_program  \
# Cluster
# 0                  2.785714     3.214286  1.785714            4.071429
# 1                  4.000000     3.000000  3.333333            4.000000
# 2                  2.444444     1.388889  2.888889            3.777778
# 3                  2.578947     3.473684  2.894737            2.421053
# 4                  1.714286     3.428571  2.857143            2.928571
# 5                  4.043478     3.782609  3.391304            3.173913
#
#          Increasing_salary  Launching_own_company  Personal_development  \
# Cluster
# 0                 4.071429               2.000000              3.357143
# 1                 3.166667               2.666667              3.000000
# 2                 3.222222               2.777778              2.333333
# 3                 1.736842               2.421053              2.157895
# 4                 2.714286               3.285714              3.928571
# 5                 3.347826               3.434783              3.869565
#
#          Changing_career  Obtaining_promotion  Benchmarking_yourself  \
# Cluster
# 0               3.285714             3.928571               3.571429
# 1               3.000000             2.583333               1.500000
# 2               3.611111             2.555556               3.333333
# 3               2.789474             3.631579               3.421053
# 4               2.071429             3.428571               1.785714
# 5               2.304348             3.130435               3.043478
#
#          Getting_out_of_office  Broadening_horizon  International_perspective  \
# Cluster
# 0                     4.000000            3.714286                   3.428571
# 1                     3.916667            3.166667                   4.250000
# 2                     2.611111            2.388889                   2.666667
# 3                     2.789474            3.526316                   2.526316
# 4                     2.642857            3.000000                   2.642857
# 5                     2.478261            2.521739                   2.434783
#
#          Improving_English  Improving_leadership_skills
# Cluster
# 0                 2.285714                     2.142857
# 1                 3.000000                     3.666667
# 2                 3.166667                     4.111111
# 3                 2.894737                     2.052632
# 4                 1.285714                     4.214286
# 5                 3.608696                     3.086957
# Silhouette Score: 0.06059866169497896

# %%
# Choosing the right number of segments using the Elbow Method
wcss = []

# Assuming df_normalized is the normalized data used for clustering
silhouette_scores = []

for i in range(2, 11):
    kmeans = KMeans(n_clusters=i, random_state=42)
    kmeans.fit(df_normalized)
    cluster_labels = kmeans.fit_predict(df_normalized)
    wcss.append(kmeans.inertia_)
    score = silhouette_score(df_normalized, cluster_labels)
    silhouette_scores.append(score)

# Plotting the Elbow Method
plt.plot(range(2, 11), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()

# Plot the silhouette scores
plt.plot(range(2, 11), silhouette_scores, marker='o')
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Score for Different Numbers of Clusters')
plt.show()

# %%
cluster_counts = dfSegmented['Cluster'].value_counts()

def autopct_format(values):
    def inner_autopct(pct):
        total = sum(values)
        count = int(pct * total / 100)
        return f'{pct:.1f}%\n({count})'
    return inner_autopct

# Plotting the pie chart
plt.figure(figsize=(8, 8))
plt.pie(cluster_counts, labels=cluster_counts.index, autopct=autopct_format(cluster_counts), startangle=90)
plt.title("Cluster Distribution")
plt.show()

# %%
# Choosing optimal clusters (e.g., from elbow point, k=6 here as an example)
kmeans = KMeans(n_clusters=6, random_state=42)
clusters = kmeans.fit_predict(df_normalized)

# Adding cluster labels to the original dataset
df['Cluster'] = clusters

# Interpretation of clusters
cluster_summary = df.groupby('Cluster').mean()
print(cluster_summary)

# Evaluating with silhouette score
sil_score = silhouette_score(df_normalized, clusters)
print(f'Silhouette Score: {sil_score}')
# Out:
#          Networking  Reputation_of_school  Changing_company  \
# Cluster
# 0          3.857143              2.142857          3.642857
# 1          1.250000              3.083333          2.416667
# 2          3.277778              2.388889          3.055556
# 3          2.105263              3.000000          2.842105
# 4          3.428571              2.428571          2.571429
# 5          3.913043              4.000000          3.260870
#
#          Academic_knowledge  Cost_driven  Location  Ranking_of_program  \
# Cluster
# 0                  2.785714     3.214286  1.785714            4.071429
# 1                  4.000000     3.000000  3.333333            4.000000
# 2                  2.444444     1.388889  2.888889            3.777778
# 3                  2.578947     3.473684  2.894737            2.421053
# 4                  1.714286     3.428571  2.857143            2.928571
# 5                  4.043478     3.782609  3.391304            3.173913
#
#          Increasing_salary  Launching_own_company  Personal_development  \
# Cluster
# 0                 4.071429               2.000000              3.357143
# 1                 3.166667               2.666667              3.000000
# 2                 3.222222               2.777778              2.333333
# 3                 1.736842               2.421053              2.157895
# 4                 2.714286               3.285714              3.928571
# 5                 3.347826               3.434783              3.869565
#
#          Changing_career  Obtaining_promotion  Benchmarking_yourself  \
# Cluster
# 0               3.285714             3.928571               3.571429
# 1               3.000000             2.583333               1.500000
# 2               3.611111             2.555556               3.333333
# 3               2.789474             3.631579               3.421053
# 4               2.071429             3.428571               1.785714
# 5               2.304348             3.130435               3.043478
#
#          Getting_out_of_office  Broadening_horizon  International_perspective  \
# Cluster
# 0                     4.000000            3.714286                   3.428571
# 1                     3.916667            3.166667                   4.250000
# 2                     2.611111            2.388889                   2.666667
# 3                     2.789474            3.526316                   2.526316
# 4                     2.642857            3.000000                   2.642857
# 5                     2.478261            2.521739                   2.434783
#
#          Improving_English  Improving_leadership_skills
# Cluster
# 0                 2.285714                     2.142857
# 1                 3.000000                     3.666667
# 2                 3.166667                     4.111111
# 3                 2.894737                     2.052632
# 4                 1.285714                     4.214286
# 5                 3.608696                     3.086957
# Silhouette Score: 0.06059866169497896

# %%
cluster_summaryTras=cluster_summary.T.round(2)
cluster_summaryTras
# Out:
# Cluster                         0     1     2     3     4     5
# Networking                   3.86  1.25  3.28  2.11  3.43  3.91
# Reputation_of_school         2.14  3.08  2.39  3.00  2.43  4.00
# Changing_company             3.64  2.42  3.06  2.84  2.57  3.26
# Academic_knowledge           2.79  4.00  2.44  2.58  1.71  4.04
# Cost_driven                  3.21  3.00  1.39  3.47  3.43  3.78
# Location                     1.79  3.33  2.89  2.89  2.86  3.39
# Ranking_of_program           4.07  4.00  3.78  2.42  2.93  3.17
# Increasing_salary            4.07  3.17  3.22  1.74  2.71  3.35
# Launching_own_company        2.00  2.67  2.78  2.42  3.29  3.43
# Personal_development         3.36  3.00  2.33  2.16  3.93  3.87
# Changing_career              3.29  3.00  3.61  2.79  2.07  2.30
# Obtaining_promotion          3.93  2.58  2.56  3.63  3.43  3.13
# Benchmarking_yourself        3.57  1.50  3.33  3.42  1.79  3.04
# Getting_out_of_office        4.00  3.92  2.61  2.79  2.64  2.48
# Broadening_horizon           3.71  3.17  2.39  3.53  3.00  2.52
# International_perspective    3.43  4.25  2.67  2.53  2.64  2.43
# Improving_English            2.29  3.00  3.17  2.89  1.29  3.61
# Improving_leadership_skills  2.14  3.67  4.11  2.05  4.21  3.09

# %%
for columna in cluster_summaryTras.columns:
    print('cluster '+str(columna))
    print(cluster_summaryTras[columna][cluster_summaryTras[columna] > 3.7])
    print('---------------------------------------------')
# Out:
# cluster 0
# Networking               3.86
# Ranking_of_program       4.07
# Increasing_salary        4.07
# Obtaining_promotion      3.93
# Getting_out_of_office    4.00
# Broadening_horizon       3.71
# Name: 0, dtype: float64
# ---------------------------------------------
# cluster 1
# Academic_knowledge           4.00
# Ranking_of_program           4.00
# Getting_out_of_office        3.92
# International_perspective    4.25
# Name: 1, dtype: float64
# ---------------------------------------------
# cluster 2
# Ranking_of_program             3.78
# Improving_leadership_skills    4.11
# Name: 2, dtype: float64
# ---------------------------------------------
# cluster 3
# Series([], Name: 3, dtype: float64)
# ---------------------------------------------
# cluster 4
# Personal_development           3.93
# Improving_leadership_skills    4.21
# Name: 4, dtype: float64
# ---------------------------------------------
# cluster 5
# Networking              3.91
# Reputation_of_school    4.00
# Academic_knowledge      4.04
# Cost_driven             3.78
# Personal_development    3.87
# Name: 5, dtype: float64
# ---------------------------------------------

# %%
for columna in cluster_summaryTras.columns:
    print('cluster '+str(columna))
    print(cluster_summaryTras[columna].sort_values(ascending=False))
    print('---------------------------------------------')
# Out:
# cluster 0
# Ranking_of_program             4.07
# Increasing_salary              4.07
# Getting_out_of_office          4.00
# Obtaining_promotion            3.93
# Networking                     3.86
# Broadening_horizon             3.71
# Changing_company               3.64
# Benchmarking_yourself          3.57
# International_perspective      3.43
# Personal_development           3.36
# Changing_career                3.29
# Cost_driven                    3.21
# Academic_knowledge             2.79
# Improving_English              2.29
# Reputation_of_school           2.14
# Improving_leadership_skills    2.14
# Launching_own_company          2.00
# Location                       1.79
# Name: 0, dtype: float64
# ---------------------------------------------
# cluster 1
# International_perspective      4.25
# Academic_knowledge             4.00
# Ranking_of_program             4.00
# Getting_out_of_office          3.92
# Improving_leadership_skills    3.67
# Location                       3.33
# Increasing_salary              3.17
# Broadening_horizon             3.17
# Reputation_of_school           3.08
# Improving_English              3.00
# Personal_development           3.00
# Changing_career                3.00
# Cost_driven                    3.00
# Launching_own_company          2.67
# Obtaining_promotion            2.58
# Changing_company               2.42
# Benchmarking_yourself          1.50
# Networking                     1.25
# Name: 1, dtype: float64
# ---------------------------------------------
# cluster 2
# Improving_leadership_skills    4.11
# Ranking_of_program             3.78
# Changing_career                3.61
# Benchmarking_yourself          3.33
# Networking                     3.28
# Increasing_salary              3.22
# Improving_English              3.17
# Changing_company               3.06
# Location                       2.89
# Launching_own_company          2.78
# International_perspective      2.67
# Getting_out_of_office          2.61
# Obtaining_promotion            2.56
# Academic_knowledge             2.44
# Reputation_of_school           2.39
# Broadening_horizon             2.39
# Personal_development           2.33
# Cost_driven                    1.39
# Name: 2, dtype: float64
# ---------------------------------------------
# cluster 3
# Obtaining_promotion            3.63
# Broadening_horizon             3.53
# Cost_driven                    3.47
# Benchmarking_yourself          3.42
# Reputation_of_school           3.00
# Location                       2.89
# Improving_English              2.89
# Changing_company               2.84
# Changing_career                2.79
# Getting_out_of_office          2.79
# Academic_knowledge             2.58
# International_perspective      2.53
# Ranking_of_program             2.42
# Launching_own_company          2.42
# Personal_development           2.16
# Networking                     2.11
# Improving_leadership_skills    2.05
# Increasing_salary              1.74
# Name: 3, dtype: float64
# ---------------------------------------------
# cluster 4
# Improving_leadership_skills    4.21
# Personal_development           3.93
# Cost_driven                    3.43
# Obtaining_promotion            3.43
# Networking                     3.43
# Launching_own_company          3.29
# Broadening_horizon             3.00
# Ranking_of_program             2.93
# Location                       2.86
# Increasing_salary              2.71
# Getting_out_of_office          2.64
# International_perspective      2.64
# Changing_company               2.57
# Reputation_of_school           2.43
# Changing_career                2.07
# Benchmarking_yourself          1.79
# Academic_knowledge             1.71
# Improving_English              1.29
# Name: 4, dtype: float64
# ---------------------------------------------
# cluster 5
# Academic_knowledge             4.04
# Reputation_of_school           4.00
# Networking                     3.91
# Personal_development           3.87
# Cost_driven                    3.78
# Improving_English              3.61
# Launching_own_company          3.43
# Location                       3.39
# Increasing_salary              3.35
# Changing_company               3.26
# Ranking_of_program             3.17
# Obtaining_promotion            3.13
# Improving_leadership_skills    3.09
# Benchmarking_yourself          3.04
# Broadening_horizon             2.52
# Getting_out_of_office          2.48
# International_perspective      2.43
# Changing_career                2.30
# Name: 5, dtype: float64
# ---------------------------------------------

# %%
correlation_matrix = cluster_summary.corr()

# Plot the heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
# Set the index to the first column (Labels)
#cluster_summaryTras.set_index('Cluster', inplace=True)'

# Create the heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(cluster_summaryTras, annot=True, cmap='RdYlGn', vmin=1, vmax=5, center=3, linewidths=0.5)

# Customize the title and labels
plt.title('Heatmap of Cluster Values', fontsize=16)
plt.xlabel('Metrics', fontsize=12)
plt.ylabel('Clusters', fontsize=12)

# Show the plot
plt.show()

# %%
cluster_summaryTras.columns
# Out:
# Index([0, 1, 2, 3, 4, 5], dtype='int32', name='Cluster')
